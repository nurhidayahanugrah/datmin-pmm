# %%
# import library
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Dataset
file_names = ['perceraian2018.xlsx', 'perceraian2019.xlsx', 'perceraian2020.xlsx', 'perceraian2021.xlsx', 'perceraian2022.xlsx']

# Membaca setiap file Excel dan menyimpannya dalam sebuah DataFrame
dataframes = [pd.read_excel(file) for file in file_names]

# %% [markdown]
# ## Preprocessing

# %%
# Menggabungkan DataFrame berdasarkan kolom 'Provinsi' dan menjumlahkan nilai-nilainya
merged_df = pd.concat(dataframes, ignore_index=True).groupby('Provinsi').sum().reset_index()

# Menyimpan hasil penggabungan ke dalam file Excel baru
merged_df.to_excel('perceraian2018-2022.xlsx', index=False)

# Menampilkan informasi tentang DataFrame hasil penggabungan
print("Jumlah baris dan kolom dataset hasil penggabungan:", merged_df.shape)
# Out:
# Jumlah baris dan kolom dataset hasil penggabungan: (35, 16)

# %%
merged_df
# Out:
#                      Provinsi  Fakor Perceraian - Zina  \
# 0                        Aceh                     11.0
# 1                        Bali                      2.0
# 2                      Banten                     43.0
# 3                    Bengkulu                     12.0
# 4               DI Yogyakarta                     33.0
# 5                 DKI Jakarta                     73.0
# 6                   Gorontalo                     13.0
# 7                   Indonesia                   4049.0
# 8                       Jambi                     18.0
# 9                  Jawa Barat                    176.0
# 10                Jawa Tengah                    417.0
# 11                 Jawa Timur                   2129.0
# 12           Kalimantan Barat                     59.0
# 13         Kalimantan Selatan                     26.0
# 14          Kalimantan Tengah                     14.0
# 15           Kalimantan Timur                     72.0
# 16           Kalimantan Utara                      0.0
# 17  Kepulauan Bangka Belitung                     25.0
# 18             Kepulauan Riau                     22.0
# 19                    Lampung                    177.0
# 20                     Maluku                      8.0
# 21               Maluku Utara                      9.0
# 22        Nusa Tenggara Barat                     21.0
# 23        Nusa Tenggara Timur                      4.0
# 24                      Papua                     61.0
# 25                Papua Barat                      0.0
# 26                       Riau                     92.0
# 27             Sulawesi Barat                      2.0
# 28           Sulawesi Selatan                     74.0
# 29            Sulawesi Tengah                      7.0
# 30          Sulawesi Tenggara                      9.0
# 31             Sulawesi Utara                     35.0
# 32             Sumatera Barat                     22.0
# 33           Sumatera Selatan                     52.0
# 34             Sumatera Utara                    331.0
#
#     Fakor Perceraian - Mabuk  Fakor Perceraian - Madat  \
# 0                       46.0                      67.0
# 1                        6.0                       0.0
# 2                      634.0                     203.0
# 3                       39.0                       9.0
# 4                       93.0                      15.0
# 5                      238.0                      71.0
# 6                      567.0                      27.0
# 7                    11019.0                    3203.0
# 8                       85.0                      35.0
# 9                      934.0                     139.0
# 10                     798.0                     287.0
# 11                    1659.0                     192.0
# 12                     138.0                      32.0
# 13                     591.0                     249.0
# 14                     213.0                      27.0
# 15                     188.0                     293.0
# 16                       5.0                       7.0
# 17                     133.0                       9.0
# 18                      34.0                       5.0
# 19                     474.0                      93.0
# 20                      32.0                       1.0
# 21                     117.0                      10.0
# 22                     431.0                      58.0
# 23                      37.0                       1.0
# 24                      98.0                       6.0
# 25                      19.0                       4.0
# 26                     150.0                      94.0
# 27                       9.0                       3.0
# 28                    1505.0                     102.0
# 29                     339.0                      54.0
# 30                     459.0                      38.0
# 31                     280.0                       3.0
# 32                      39.0                      31.0
# 33                     325.0                     180.0
# 34                     304.0                     858.0
#
#     Fakor Perceraian - Judi  Fakor Perceraian - Meninggalkan Salah satu Pihak  \
# 0                      54.0                                            4117.0
# 1                       0.0                                             232.0
# 2                     425.0                                            6622.0
# 3                      47.0                                            1854.0
# 4                      40.0                                            4656.0
# 5                     121.0                                            9772.0
# 6                      23.0                                            2088.0
# 7                    6942.0                                          248545.0
# 8                      87.0                                            2945.0
# 9                     768.0                                           27667.0
# 10                    601.0                                           69708.0
# 11                   1249.0                                           40806.0
# 12                    150.0                                            3156.0
# 13                    100.0                                            3180.0
# 14                     56.0                                            2462.0
# 15                    199.0                                            6506.0
# 16                      0.0                                             239.0
# 17                     52.0                                             984.0
# 18                     34.0                                             522.0
# 19                    643.0                                            5287.0
# 20                     23.0                                             530.0
# 21                     11.0                                            1514.0
# 22                    248.0                                            6458.0
# 23                     11.0                                             663.0
# 24                     38.0                                            1492.0
# 25                      3.0                                              81.0
# 26                    167.0                                            5887.0
# 27                      2.0                                             370.0
# 28                    743.0                                           14313.0
# 29                     76.0                                            2138.0
# 30                     77.0                                            2811.0
# 31                     21.0                                            1156.0
# 32                    127.0                                            5153.0
# 33                    383.0                                            3867.0
# 34                    363.0                                            9309.0
#
#     Fakor Perceraian - Dihukum Penjara  Fakor Perceraian - Poligami  \
# 0                                345.0                        131.0
# 1                                  2.0                          1.0
# 2                                224.0                        631.0
# 3                                 74.0                         24.0
# 4                                 44.0                         24.0
# 5                                187.0                        149.0
# 6                                 12.0                         41.0
# 7                               8474.0                       5067.0
# 8                                144.0                         48.0
# 9                                591.0                        899.0
# 10                              2663.0                        309.0
# 11                               801.0                        613.0
# 12                               149.0                         88.0
# 13                               384.0                        300.0
# 14                               137.0                         70.0
# 15                               586.0                        335.0
# 16                                21.0                          5.0
# 17                               109.0                         53.0
# 18                                40.0                          6.0
# 19                               135.0                        111.0
# 20                                 4.0                         16.0
# 21                                12.0                         17.0
# 22                               160.0                        245.0
# 23                                22.0                          5.0
# 24                                22.0                         13.0
# 25                                 0.0                          0.0
# 26                               376.0                         96.0
# 27                                 5.0                          7.0
# 28                               216.0                        364.0
# 29                                44.0                         71.0
# 30                                44.0                         68.0
# 31                                22.0                         14.0
# 32                               163.0                         72.0
# 33                               336.0                        184.0
# 34                               400.0                         57.0
#
#     Fakor Perceraian - Kekerasan Dalam Rumah Tangga  \
# 0                                             533.0
# 1                                              14.0
# 2                                            2404.0
# 3                                             122.0
# 4                                             291.0
# 5                                            1708.0
# 6                                             234.0
# 7                                           29600.0
# 8                                             286.0
# 9                                            3052.0
# 10                                           1686.0
# 11                                           6598.0
# 12                                            260.0
# 13                                            364.0
# 14                                            217.0
# 15                                           1049.0
# 16                                              7.0
# 17                                            262.0
# 18                                             39.0
# 19                                           1278.0
# 20                                            138.0
# 21                                            252.0
# 22                                           1506.0
# 23                                             59.0
# 24                                            157.0
# 25                                             16.0
# 26                                            630.0
# 27                                             49.0
# 28                                           2820.0
# 29                                            519.0
# 30                                            941.0
# 31                                            245.0
# 32                                            375.0
# 33                                           1077.0
# 34                                            412.0
#
#     Fakor Perceraian - Cacat Badan  \
# 0                             83.0
# 1                              1.0
# 2                             46.0
# 3                             12.0
# 4                             27.0
# 5                             28.0
# 6                              0.0
# 7                           2058.0
# 8                             14.0
# 9                            139.0
# 10                           326.0
# 11                           654.0
# 12                            16.0
# 13                            46.0
# 14                            28.0
# 15                            38.0
# 16                             0.0
# 17                             4.0
# 18                             1.0
# 19                           204.0
# 20                             1.0
# 21                             2.0
# 22                            17.0
# 23                             3.0
# 24                            10.0
# 25                             0.0
# 26                            56.0
# 27                             1.0
# 28                           170.0
# 29                            11.0
# 30                            26.0
# 31                             3.0
# 32                            40.0
# 33                            28.0
# 34                            23.0
#
#     Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus  \
# 0                                             21667.0
# 1                                               869.0
# 2                                             43106.0
# 3                                             13637.0
# 4                                             18673.0
# 5                                             45287.0
# 6                                              7103.0
# 7                                           1155014.0
# 8                                             18349.0
# 9                                            188719.0
# 10                                           178575.0
# 11                                           206776.0
# 12                                            17966.0
# 13                                            25321.0
# 14                                            10630.0
# 15                                            23635.0
# 16                                             1036.0
# 17                                             9118.0
# 18                                             2574.0
# 19                                            41064.0
# 20                                             2082.0
# 21                                             3173.0
# 22                                            24307.0
# 23                                             1402.0
# 24                                             5117.0
# 25                                              317.0
# 26                                            39784.0
# 27                                              786.0
# 28                                            40629.0
# 29                                            12027.0
# 30                                            11191.0
# 31                                             6015.0
# 32                                            31693.0
# 33                                            35231.0
# 34                                            60155.0
#
#     Fakor Perceraian - Kawin Paksa  Fakor Perceraian - Murtad  \
# 0                              8.0                       31.0
# 1                              1.0                        9.0
# 2                             34.0                      309.0
# 3                             19.0                       25.0
# 4                             25.0                       95.0
# 5                             12.0                      272.0
# 6                             10.0                       45.0
# 7                           2863.0                     6244.0
# 8                              8.0                       51.0
# 9                            137.0                     1005.0
# 10                           766.0                      887.0
# 11                          1179.0                     1134.0
# 12                            18.0                       98.0
# 13                            96.0                      123.0
# 14                            17.0                      140.0
# 15                            54.0                      194.0
# 16                             1.0                       10.0
# 17                             4.0                       38.0
# 18                             1.0                       11.0
# 19                            18.0                      219.0
# 20                             2.0                       17.0
# 21                            11.0                        9.0
# 22                            44.0                      144.0
# 23                            19.0                       25.0
# 24                            10.0                       95.0
# 25                             2.0                        2.0
# 26                            48.0                      115.0
# 27                             1.0                        7.0
# 28                           209.0                      197.0
# 29                            20.0                      110.0
# 30                             8.0                       60.0
# 31                            17.0                      271.0
# 32                            28.0                       42.0
# 33                            22.0                      166.0
# 34                            14.0                      288.0
#
#     Fakor Perceraian - Ekonomi  Fakor Perceraian - Lain-lain  \
# 0                       1521.0                         161.0
# 1                         74.0                           0.0
# 2                      14154.0                           0.0
# 3                       1001.0                           0.0
# 4                       4110.0                           0.0
# 5                      13449.0                           0.0
# 6                        254.0                           0.0
# 7                     527117.0                        7974.0
# 8                       1934.0                           0.0
# 9                     172641.0                        5291.0
# 10                    111786.0                          17.0
# 11                    156803.0                        1715.0
# 12                      2556.0                           3.0
# 13                      3107.0                           7.0
# 14                       885.0                           5.0
# 15                      5501.0                          16.0
# 16                        29.0                           4.0
# 17                      1150.0                           0.0
# 18                       208.0                           0.0
# 19                     14353.0                           0.0
# 20                        33.0                           1.0
# 21                       104.0                           0.0
# 22                      2889.0                          20.0
# 23                        40.0                           0.0
# 24                       533.0                           0.0
# 25                        84.0                           0.0
# 26                      3618.0                           0.0
# 27                        34.0                           0.0
# 28                      3897.0                           7.0
# 29                       503.0                         184.0
# 30                       818.0                           0.0
# 31                       238.0                          13.0
# 32                      1841.0                           0.0
# 33                      3917.0                          15.0
# 34                      3052.0                         515.0
#
#     Fakor Perceraian - Jumlah
# 0                     28775.0
# 1                      1211.0
# 2                     68835.0
# 3                     16875.0
# 4                     28126.0
# 5                     71367.0
# 6                     10417.0
# 7                   2018169.0
# 8                     24004.0
# 9                    402158.0
# 10                   368826.0
# 11                   422308.0
# 12                    24689.0
# 13                    33894.0
# 14                    14901.0
# 15                    38666.0
# 16                     1364.0
# 17                    11941.0
# 18                     3497.0
# 19                    64056.0
# 20                     2888.0
# 21                     5241.0
# 22                    36548.0
# 23                     2291.0
# 24                     7652.0
# 25                      528.0
# 26                    51113.0
# 27                     1276.0
# 28                    72246.0
# 29                    16103.0
# 30                    16550.0
# 31                     8333.0
# 32                    39626.0
# 33                    45783.0
# 34                    76081.0

# %%
merged_df = merged_df[merged_df.index != 7].reset_index(drop=True)
merged_df
# Out:
#                      Provinsi  Fakor Perceraian - Zina  \
# 0                        Aceh                     11.0
# 1                        Bali                      2.0
# 2                      Banten                     43.0
# 3                    Bengkulu                     12.0
# 4               DI Yogyakarta                     33.0
# 5                 DKI Jakarta                     73.0
# 6                   Gorontalo                     13.0
# 7                       Jambi                     18.0
# 8                  Jawa Barat                    176.0
# 9                 Jawa Tengah                    417.0
# 10                 Jawa Timur                   2129.0
# 11           Kalimantan Barat                     59.0
# 12         Kalimantan Selatan                     26.0
# 13          Kalimantan Tengah                     14.0
# 14           Kalimantan Timur                     72.0
# 15           Kalimantan Utara                      0.0
# 16  Kepulauan Bangka Belitung                     25.0
# 17             Kepulauan Riau                     22.0
# 18                    Lampung                    177.0
# 19                     Maluku                      8.0
# 20               Maluku Utara                      9.0
# 21        Nusa Tenggara Barat                     21.0
# 22        Nusa Tenggara Timur                      4.0
# 23                      Papua                     61.0
# 24                Papua Barat                      0.0
# 25                       Riau                     92.0
# 26             Sulawesi Barat                      2.0
# 27           Sulawesi Selatan                     74.0
# 28            Sulawesi Tengah                      7.0
# 29          Sulawesi Tenggara                      9.0
# 30             Sulawesi Utara                     35.0
# 31             Sumatera Barat                     22.0
# 32           Sumatera Selatan                     52.0
# 33             Sumatera Utara                    331.0
#
#     Fakor Perceraian - Mabuk  Fakor Perceraian - Madat  \
# 0                       46.0                      67.0
# 1                        6.0                       0.0
# 2                      634.0                     203.0
# 3                       39.0                       9.0
# 4                       93.0                      15.0
# 5                      238.0                      71.0
# 6                      567.0                      27.0
# 7                       85.0                      35.0
# 8                      934.0                     139.0
# 9                      798.0                     287.0
# 10                    1659.0                     192.0
# 11                     138.0                      32.0
# 12                     591.0                     249.0
# 13                     213.0                      27.0
# 14                     188.0                     293.0
# 15                       5.0                       7.0
# 16                     133.0                       9.0
# 17                      34.0                       5.0
# 18                     474.0                      93.0
# 19                      32.0                       1.0
# 20                     117.0                      10.0
# 21                     431.0                      58.0
# 22                      37.0                       1.0
# 23                      98.0                       6.0
# 24                      19.0                       4.0
# 25                     150.0                      94.0
# 26                       9.0                       3.0
# 27                    1505.0                     102.0
# 28                     339.0                      54.0
# 29                     459.0                      38.0
# 30                     280.0                       3.0
# 31                      39.0                      31.0
# 32                     325.0                     180.0
# 33                     304.0                     858.0
#
#     Fakor Perceraian - Judi  Fakor Perceraian - Meninggalkan Salah satu Pihak  \
# 0                      54.0                                            4117.0
# 1                       0.0                                             232.0
# 2                     425.0                                            6622.0
# 3                      47.0                                            1854.0
# 4                      40.0                                            4656.0
# 5                     121.0                                            9772.0
# 6                      23.0                                            2088.0
# 7                      87.0                                            2945.0
# 8                     768.0                                           27667.0
# 9                     601.0                                           69708.0
# 10                   1249.0                                           40806.0
# 11                    150.0                                            3156.0
# 12                    100.0                                            3180.0
# 13                     56.0                                            2462.0
# 14                    199.0                                            6506.0
# 15                      0.0                                             239.0
# 16                     52.0                                             984.0
# 17                     34.0                                             522.0
# 18                    643.0                                            5287.0
# 19                     23.0                                             530.0
# 20                     11.0                                            1514.0
# 21                    248.0                                            6458.0
# 22                     11.0                                             663.0
# 23                     38.0                                            1492.0
# 24                      3.0                                              81.0
# 25                    167.0                                            5887.0
# 26                      2.0                                             370.0
# 27                    743.0                                           14313.0
# 28                     76.0                                            2138.0
# 29                     77.0                                            2811.0
# 30                     21.0                                            1156.0
# 31                    127.0                                            5153.0
# 32                    383.0                                            3867.0
# 33                    363.0                                            9309.0
#
#     Fakor Perceraian - Dihukum Penjara  Fakor Perceraian - Poligami  \
# 0                                345.0                        131.0
# 1                                  2.0                          1.0
# 2                                224.0                        631.0
# 3                                 74.0                         24.0
# 4                                 44.0                         24.0
# 5                                187.0                        149.0
# 6                                 12.0                         41.0
# 7                                144.0                         48.0
# 8                                591.0                        899.0
# 9                               2663.0                        309.0
# 10                               801.0                        613.0
# 11                               149.0                         88.0
# 12                               384.0                        300.0
# 13                               137.0                         70.0
# 14                               586.0                        335.0
# 15                                21.0                          5.0
# 16                               109.0                         53.0
# 17                                40.0                          6.0
# 18                               135.0                        111.0
# 19                                 4.0                         16.0
# 20                                12.0                         17.0
# 21                               160.0                        245.0
# 22                                22.0                          5.0
# 23                                22.0                         13.0
# 24                                 0.0                          0.0
# 25                               376.0                         96.0
# 26                                 5.0                          7.0
# 27                               216.0                        364.0
# 28                                44.0                         71.0
# 29                                44.0                         68.0
# 30                                22.0                         14.0
# 31                               163.0                         72.0
# 32                               336.0                        184.0
# 33                               400.0                         57.0
#
#     Fakor Perceraian - Kekerasan Dalam Rumah Tangga  \
# 0                                             533.0
# 1                                              14.0
# 2                                            2404.0
# 3                                             122.0
# 4                                             291.0
# 5                                            1708.0
# 6                                             234.0
# 7                                             286.0
# 8                                            3052.0
# 9                                            1686.0
# 10                                           6598.0
# 11                                            260.0
# 12                                            364.0
# 13                                            217.0
# 14                                           1049.0
# 15                                              7.0
# 16                                            262.0
# 17                                             39.0
# 18                                           1278.0
# 19                                            138.0
# 20                                            252.0
# 21                                           1506.0
# 22                                             59.0
# 23                                            157.0
# 24                                             16.0
# 25                                            630.0
# 26                                             49.0
# 27                                           2820.0
# 28                                            519.0
# 29                                            941.0
# 30                                            245.0
# 31                                            375.0
# 32                                           1077.0
# 33                                            412.0
#
#     Fakor Perceraian - Cacat Badan  \
# 0                             83.0
# 1                              1.0
# 2                             46.0
# 3                             12.0
# 4                             27.0
# 5                             28.0
# 6                              0.0
# 7                             14.0
# 8                            139.0
# 9                            326.0
# 10                           654.0
# 11                            16.0
# 12                            46.0
# 13                            28.0
# 14                            38.0
# 15                             0.0
# 16                             4.0
# 17                             1.0
# 18                           204.0
# 19                             1.0
# 20                             2.0
# 21                            17.0
# 22                             3.0
# 23                            10.0
# 24                             0.0
# 25                            56.0
# 26                             1.0
# 27                           170.0
# 28                            11.0
# 29                            26.0
# 30                             3.0
# 31                            40.0
# 32                            28.0
# 33                            23.0
#
#     Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus  \
# 0                                             21667.0
# 1                                               869.0
# 2                                             43106.0
# 3                                             13637.0
# 4                                             18673.0
# 5                                             45287.0
# 6                                              7103.0
# 7                                             18349.0
# 8                                            188719.0
# 9                                            178575.0
# 10                                           206776.0
# 11                                            17966.0
# 12                                            25321.0
# 13                                            10630.0
# 14                                            23635.0
# 15                                             1036.0
# 16                                             9118.0
# 17                                             2574.0
# 18                                            41064.0
# 19                                             2082.0
# 20                                             3173.0
# 21                                            24307.0
# 22                                             1402.0
# 23                                             5117.0
# 24                                              317.0
# 25                                            39784.0
# 26                                              786.0
# 27                                            40629.0
# 28                                            12027.0
# 29                                            11191.0
# 30                                             6015.0
# 31                                            31693.0
# 32                                            35231.0
# 33                                            60155.0
#
#     Fakor Perceraian - Kawin Paksa  Fakor Perceraian - Murtad  \
# 0                              8.0                       31.0
# 1                              1.0                        9.0
# 2                             34.0                      309.0
# 3                             19.0                       25.0
# 4                             25.0                       95.0
# 5                             12.0                      272.0
# 6                             10.0                       45.0
# 7                              8.0                       51.0
# 8                            137.0                     1005.0
# 9                            766.0                      887.0
# 10                          1179.0                     1134.0
# 11                            18.0                       98.0
# 12                            96.0                      123.0
# 13                            17.0                      140.0
# 14                            54.0                      194.0
# 15                             1.0                       10.0
# 16                             4.0                       38.0
# 17                             1.0                       11.0
# 18                            18.0                      219.0
# 19                             2.0                       17.0
# 20                            11.0                        9.0
# 21                            44.0                      144.0
# 22                            19.0                       25.0
# 23                            10.0                       95.0
# 24                             2.0                        2.0
# 25                            48.0                      115.0
# 26                             1.0                        7.0
# 27                           209.0                      197.0
# 28                            20.0                      110.0
# 29                             8.0                       60.0
# 30                            17.0                      271.0
# 31                            28.0                       42.0
# 32                            22.0                      166.0
# 33                            14.0                      288.0
#
#     Fakor Perceraian - Ekonomi  Fakor Perceraian - Lain-lain  \
# 0                       1521.0                         161.0
# 1                         74.0                           0.0
# 2                      14154.0                           0.0
# 3                       1001.0                           0.0
# 4                       4110.0                           0.0
# 5                      13449.0                           0.0
# 6                        254.0                           0.0
# 7                       1934.0                           0.0
# 8                     172641.0                        5291.0
# 9                     111786.0                          17.0
# 10                    156803.0                        1715.0
# 11                      2556.0                           3.0
# 12                      3107.0                           7.0
# 13                       885.0                           5.0
# 14                      5501.0                          16.0
# 15                        29.0                           4.0
# 16                      1150.0                           0.0
# 17                       208.0                           0.0
# 18                     14353.0                           0.0
# 19                        33.0                           1.0
# 20                       104.0                           0.0
# 21                      2889.0                          20.0
# 22                        40.0                           0.0
# 23                       533.0                           0.0
# 24                        84.0                           0.0
# 25                      3618.0                           0.0
# 26                        34.0                           0.0
# 27                      3897.0                           7.0
# 28                       503.0                         184.0
# 29                       818.0                           0.0
# 30                       238.0                          13.0
# 31                      1841.0                           0.0
# 32                      3917.0                          15.0
# 33                      3052.0                         515.0
#
#     Fakor Perceraian - Jumlah
# 0                     28775.0
# 1                      1211.0
# 2                     68835.0
# 3                     16875.0
# 4                     28126.0
# 5                     71367.0
# 6                     10417.0
# 7                     24004.0
# 8                    402158.0
# 9                    368826.0
# 10                   422308.0
# 11                    24689.0
# 12                    33894.0
# 13                    14901.0
# 14                    38666.0
# 15                     1364.0
# 16                    11941.0
# 17                     3497.0
# 18                    64056.0
# 19                     2888.0
# 20                     5241.0
# 21                    36548.0
# 22                     2291.0
# 23                     7652.0
# 24                      528.0
# 25                    51113.0
# 26                     1276.0
# 27                    72246.0
# 28                    16103.0
# 29                    16550.0
# 30                     8333.0
# 31                    39626.0
# 32                    45783.0
# 33                    76081.0

# %%
# # Normalisasi

# from sklearn.preprocessing import MinMaxScaler # normalisasi
# scaler = MinMaxScaler()

# normalize_data = scaler.fit_transform(merged_df[['Fakor Perceraian - Zina', 'Fakor Perceraian - Mabuk', 'Fakor Perceraian - Madat',
#                            'Fakor Perceraian - Judi', 'Fakor Perceraian - Meninggalkan Salah satu Pihak',
#                            'Fakor Perceraian - Dihukum Penjara', 'Fakor Perceraian - Poligami',
#                            'Fakor Perceraian - Kekerasan Dalam Rumah Tangga', 'Fakor Perceraian - Cacat Badan',
#                            'Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus',
#                            'Fakor Perceraian - Kawin Paksa', 'Fakor Perceraian - Murtad',
#                            'Fakor Perceraian - Ekonomi', 'Fakor Perceraian - Lain-lain']])

# normalize_data = pd.DataFrame(normalize_data)

# normalize_data.head()

# %% [markdown]
# ### Normalisasi

# %%
from sklearn.preprocessing import MinMaxScaler

# Separate numeric and non-numeric columns
numeric_columns = merged_df.select_dtypes(include=['float64', 'int64']).columns
non_numeric_columns = [col for col in merged_df.columns if col not in numeric_columns]

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Normalize numeric columns
df_normalized_numeric = pd.DataFrame(scaler.fit_transform(merged_df[numeric_columns]), columns=numeric_columns)

# Combine the normalized numeric columns with the non-numeric columns
df_normalized = pd.concat([merged_df[non_numeric_columns], df_normalized_numeric], axis=1)

# Display the result
print("Original DataFrame:")
merged_df.head(5)
# Out:
# Original DataFrame:
#         Provinsi  Fakor Perceraian - Zina  Fakor Perceraian - Mabuk  \
# 0           Aceh                     11.0                      46.0
# 1           Bali                      2.0                       6.0
# 2         Banten                     43.0                     634.0
# 3       Bengkulu                     12.0                      39.0
# 4  DI Yogyakarta                     33.0                      93.0
#
#    Fakor Perceraian - Madat  Fakor Perceraian - Judi  \
# 0                      67.0                     54.0
# 1                       0.0                      0.0
# 2                     203.0                    425.0
# 3                       9.0                     47.0
# 4                      15.0                     40.0
#
#    Fakor Perceraian - Meninggalkan Salah satu Pihak  \
# 0                                            4117.0
# 1                                             232.0
# 2                                            6622.0
# 3                                            1854.0
# 4                                            4656.0
#
#    Fakor Perceraian - Dihukum Penjara  Fakor Perceraian - Poligami  \
# 0                               345.0                        131.0
# 1                                 2.0                          1.0
# 2                               224.0                        631.0
# 3                                74.0                         24.0
# 4                                44.0                         24.0
#
#    Fakor Perceraian - Kekerasan Dalam Rumah Tangga  \
# 0                                            533.0
# 1                                             14.0
# 2                                           2404.0
# 3                                            122.0
# 4                                            291.0
#
#    Fakor Perceraian - Cacat Badan  \
# 0                            83.0
# 1                             1.0
# 2                            46.0
# 3                            12.0
# 4                            27.0
#
#    Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus  \
# 0                                            21667.0
# 1                                              869.0
# 2                                            43106.0
# 3                                            13637.0
# 4                                            18673.0
#
#    Fakor Perceraian - Kawin Paksa  Fakor Perceraian - Murtad  \
# 0                             8.0                       31.0
# 1                             1.0                        9.0
# 2                            34.0                      309.0
# 3                            19.0                       25.0
# 4                            25.0                       95.0
#
#    Fakor Perceraian - Ekonomi  Fakor Perceraian - Lain-lain  \
# 0                      1521.0                         161.0
# 1                        74.0                           0.0
# 2                     14154.0                           0.0
# 3                      1001.0                           0.0
# 4                      4110.0                           0.0
#
#    Fakor Perceraian - Jumlah
# 0                    28775.0
# 1                     1211.0
# 2                    68835.0
# 3                    16875.0
# 4                    28126.0

# %%
print("\nNormalized DataFrame:")
df_normalized.head(5)
# Out:
# Normalized DataFrame:
#         Provinsi  Fakor Perceraian - Zina  Fakor Perceraian - Mabuk  \
# 0           Aceh                 0.005167                  0.024788
# 1           Bali                 0.000939                  0.000605
# 2         Banten                 0.020197                  0.380290
# 3       Bengkulu                 0.005636                  0.020556
# 4  DI Yogyakarta                 0.015500                  0.053204
#
#    Fakor Perceraian - Madat  Fakor Perceraian - Judi  \
# 0                  0.078089                 0.043235
# 1                  0.000000                 0.000000
# 2                  0.236597                 0.340272
# 3                  0.010490                 0.037630
# 4                  0.017483                 0.032026
#
#    Fakor Perceraian - Meninggalkan Salah satu Pihak  \
# 0                                          0.057966
# 1                                          0.002169
# 2                                          0.093943
# 3                                          0.025464
# 4                                          0.065707
#
#    Fakor Perceraian - Dihukum Penjara  Fakor Perceraian - Poligami  \
# 0                            0.129553                     0.145717
# 1                            0.000751                     0.001112
# 2                            0.084116                     0.701891
# 3                            0.027788                     0.026696
# 4                            0.016523                     0.026696
#
#    Fakor Perceraian - Kekerasan Dalam Rumah Tangga  \
# 0                                         0.079806
# 1                                         0.001062
# 2                                         0.363678
# 3                                         0.017448
# 4                                         0.043089
#
#    Fakor Perceraian - Cacat Badan  \
# 0                        0.126911
# 1                        0.001529
# 2                        0.070336
# 3                        0.018349
# 4                        0.041284
#
#    Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus  \
# 0                                           0.103410
# 1                                           0.002674
# 2                                           0.207252
# 3                                           0.064516
# 4                                           0.088909
#
#    Fakor Perceraian - Kawin Paksa  Fakor Perceraian - Murtad  \
# 0                        0.005942                   0.025618
# 1                        0.000000                   0.006184
# 2                        0.028014                   0.271201
# 3                        0.015280                   0.020318
# 4                        0.020374                   0.082155
#
#    Fakor Perceraian - Ekonomi  Fakor Perceraian - Lain-lain  \
# 0                    0.008644                      0.030429
# 1                    0.000261                      0.000000
# 2                    0.081831                      0.000000
# 3                    0.005631                      0.000000
# 4                    0.023643                      0.000000
#
#    Fakor Perceraian - Jumlah
# 0                   0.066971
# 1                   0.001619
# 2                   0.161949
# 3                   0.038757
# 4                   0.065432

# %%
df_normalized.shape
# Out:
# (34, 16)

# %%
df_normalized.isnull().sum()
# Out:
# Provinsi                                                          0
# Fakor Perceraian - Zina                                           0
# Fakor Perceraian - Mabuk                                          0
# Fakor Perceraian - Madat                                          0
# Fakor Perceraian - Judi                                           0
# Fakor Perceraian - Meninggalkan Salah satu Pihak                  0
# Fakor Perceraian - Dihukum Penjara                                0
# Fakor Perceraian - Poligami                                       0
# Fakor Perceraian - Kekerasan Dalam Rumah Tangga                   0
# Fakor Perceraian - Cacat Badan                                    0
# Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus    0
# Fakor Perceraian - Kawin Paksa                                    0
# Fakor Perceraian - Murtad                                         0
# Fakor Perceraian - Ekonomi                                        0
# Fakor Perceraian - Lain-lain                                      0
# Fakor Perceraian - Jumlah                                         0
# dtype: int64

# %%
# # Plot bar chart
# fig, ax = plt.subplots(figsize=(20, 6))

# # Set the width of the bars
# bar_width = 0.25

# # Set the position of the bars on the x-axis
# r1 = range(len(merged_df))
# r2 = [x + bar_width for x in r1]
# r3 = [x + bar_width for x in r2]
# r4 = [x + bar_width for x in r3]
# r5 = [x + bar_width for x in r4]
# r6 = [x + bar_width for x in r5]
# r7 = [x + bar_width for x in r6]
# r8 = [x + bar_width for x in r7]
# r9 = [x + bar_width for x in r8]
# r10 = [x + bar_width for x in r9]
# r11 = [x + bar_width for x in r10]
# r12 = [x + bar_width for x in r11]
# r13 = [x + bar_width for x in r12]

# # Plot each bar
# plt.bar(r1, merged_df['Fakor Perceraian - Zina'], color='blue', width=bar_width, edgecolor='grey', label='Zina')
# plt.bar(r2, merged_df['Fakor Perceraian - Mabuk'], color='orange', width=bar_width, edgecolor='grey', label='Mabuk')
# plt.bar(r3, merged_df['Fakor Perceraian - Madat'], color='green', width=bar_width, edgecolor='grey', label='Madat')
# plt.bar(r4, merged_df['Fakor Perceraian - Meninggalkan Salah satu Pihak'], color='blue', width=bar_width, edgecolor='grey', label='Meninggalkan Salah satu Pihak')
# plt.bar(r5, merged_df['Fakor Perceraian - Dihukum Penjara'], color='blue', width=bar_width, edgecolor='grey', label='Dihukum Penjara')
# plt.bar(r6, merged_df['Fakor Perceraian - Poligami'], color='blue', width=bar_width, edgecolor='grey', label='Poligami')
# plt.bar(r7, merged_df['Fakor Perceraian - Kekerasan Dalam Rumah Tangga'], color='blue', width=bar_width, edgecolor='grey', label='KDRT')
# plt.bar(r8, merged_df['Fakor Perceraian - Cacat Badan'], color='blue', width=bar_width, edgecolor='grey', label='Cacat Badan')
# plt.bar(r9, merged_df['Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus'], color='blue', width=bar_width, edgecolor='grey', label='Perselisihan')
# plt.bar(r10, merged_df['Fakor Perceraian - Kawin Paksa'], color='blue', width=bar_width, edgecolor='grey', label='Kawin Paksa')
# plt.bar(r11, merged_df['Fakor Perceraian - Murtad'], color='blue', width=bar_width, edgecolor='grey', label='Zina')
# plt.bar(r12, merged_df['Fakor Perceraian - Ekonomi'], color='blue', width=bar_width, edgecolor='grey', label='Zina')
# plt.bar(r13, merged_df['Fakor Perceraian - Lain-lain'], color='blue', width=bar_width, edgecolor='grey', label='Zina')



# # Set axis labels and title
# plt.xlabel('Provinsi', fontweight='bold')
# plt.xticks([r + bar_width for r in range(len(merged_df))], merged_df['Provinsi'])
# plt.ylabel('Jumlah Perceraian')
# plt.title('Jumlah Perceraian Berdasarkan Faktor di Setiap Provinsi')

# # Add legend
# plt.legend()

# # Show the plot
# plt.show()

# %%
datav= merged_df.copy()

# Menambahkan satu baris baru untuk total dari semua provinsi
datav.loc['Total'] = datav.iloc[:, 1:].sum(axis=0)

# Mengambil total dari baris terakhir menggunakan iloc
total_semua = datav.iloc[-1]

# Menghilangkan kolom yang tidak diperlukan
total_semua = total_semua.drop(['Provinsi', 'Fakor Perceraian - Jumlah'])

print(total_semua)
# Out:
# Fakor Perceraian - Zina                                              4049.0
# Fakor Perceraian - Mabuk                                            11019.0
# Fakor Perceraian - Madat                                             3203.0
# Fakor Perceraian - Judi                                              6942.0
# Fakor Perceraian - Meninggalkan Salah satu Pihak                   248545.0
# Fakor Perceraian - Dihukum Penjara                                   8474.0
# Fakor Perceraian - Poligami                                          5067.0
# Fakor Perceraian - Kekerasan Dalam Rumah Tangga                     29600.0
# Fakor Perceraian - Cacat Badan                                       2058.0
# Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus    1148014.0
# Fakor Perceraian - Kawin Paksa                                       2863.0
# Fakor Perceraian - Murtad                                            6244.0
# Fakor Perceraian - Ekonomi                                         527117.0
# Fakor Perceraian - Lain-lain                                         7974.0
# Name: Total, dtype: object

# %%
import matplotlib.pyplot as plt

# Menggunakan data total_semua yang telah dihasilkan
fig, ax = plt.subplots(figsize=(20, 10))
bars = total_semua.plot(kind='barh', color=['blue', 'green', 'orange', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow', 'lightblue', 'darkgreen', 'lightcoral', 'darkorange'], edgecolor='grey', ax=ax)

# Menambahkan label dan judul
plt.xlabel('Jumlah Perceraian', fontweight='bold')
plt.ylabel('Faktor Perceraian')
plt.title('Jumlah Perceraian Berdasarkan Faktor')

# Menambahkan nilai x di samping setiap bar
for bar in bars.patches:
    plt.text(bar.get_width() + 0.1, bar.get_y() + bar.get_height() / 2 - 0.1, str(int(bar.get_width())),
             fontsize=9, color='black')

# Menampilkan diagram batang
plt.show()

# %%
# # Memilih kolom yang akan digunakan untuk klastering
# columns_for_clustering = ['Fakor Perceraian - Meninggalkan Salah satu Pihak',
#                            'Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus',
#                            'Fakor Perceraian - Ekonomi']

# # Memilih data yang akan digunakan untuk klastering
# data_for_clustering = df_normalized[columns_for_clustering]

# %%
# # Assuming merged_df is your DataFrame with factors related to divorce
# # Adjust the features accordingly
# features = ['Fakor Perceraian - Zina', 'Fakor Perceraian - Mabuk', 'Fakor Perceraian - Madat',
#                            'Fakor Perceraian - Judi', 'Fakor Perceraian - Meninggalkan Salah satu Pihak',
#                            'Fakor Perceraian - Dihukum Penjara', 'Fakor Perceraian - Poligami',
#                            'Fakor Perceraian - Kekerasan Dalam Rumah Tangga', 'Fakor Perceraian - Cacat Badan',
#                            'Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus',
#                            'Fakor Perceraian - Kawin Paksa', 'Fakor Perceraian - Murtad',
#                            'Fakor Perceraian - Ekonomi', 'Fakor Perceraian - Lain-lain']

# # Extract the relevant features
# X = df_normalized[features]

# # Specify the number of clusters
# n_clusters = 3  # You can adjust this based on your requirements

# # Apply K-Means clustering
# kmeans = KMeans(n_clusters=n_clusters, random_state=42)
# df_normalized['Cluster'] = kmeans.fit_predict(X)

# # Visualize the clusters
# for cluster in range(n_clusters):
#     cluster_data = df_normalized[df_normalized['Cluster'] == cluster]
#     plt.scatter(cluster_data[features[0]], cluster_data[features[1]], label=f'Cluster {cluster + 1}')

# plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')
# plt.title('K-Means Clustering of Provinces based on Divorce Factors')
# plt.xlabel(features[0])
# plt.ylabel(features[1])
# plt.legend()
# plt.show()

# %% [markdown]
# ## Kmeans Clustering

# %%
# # Memilih kolom faktor perceraian untuk analisis clustering
# faktor_columns = df_normalized.columns[1:]

# # Standarisasi data
# scaler = StandardScaler()
# df_normalized[faktor_columns] = scaler.fit_transform(df_normalized[faktor_columns])

# # Menentukan jumlah cluster yang diinginkan
# jumlah_cluster = 3

# # Membuat model K-Means dengan jumlah cluster tertentu
# kmeans = KMeans(n_clusters=jumlah_cluster, random_state=42)

# # Melakukan clustering berdasarkan faktor perceraian
# df_normalized['Cluster'] = kmeans.fit_predict(df_normalized[faktor_columns])

# # Menampilkan hasil clustering
# print(df_normalized[['Provinsi', 'Cluster']])

# # Visualisasi hasil clustering
# for cluster in range(jumlah_cluster):
#     cluster_data = df_normalized[df_normalized['Cluster'] == cluster]
#     plt.scatter(cluster_data[faktor_columns[0]], cluster_data[faktor_columns[1]], label=f'Cluster {cluster}')

# plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', s=200, c='red', label='Centroids')
# plt.xlabel(faktor_columns[0])
# plt.ylabel(faktor_columns[1])
# plt.title('Hasil Clustering Faktor Perceraian')
# plt.legend()
# plt.show()

# %%
colums_for_clustering = ['Fakor Perceraian - Zina', 'Fakor Perceraian - Mabuk', 'Fakor Perceraian - Madat',
                           'Fakor Perceraian - Judi', 'Fakor Perceraian - Meninggalkan Salah satu Pihak',
                           'Fakor Perceraian - Dihukum Penjara', 'Fakor Perceraian - Poligami',
                           'Fakor Perceraian - Kekerasan Dalam Rumah Tangga', 'Fakor Perceraian - Cacat Badan',
                           'Fakor Perceraian - Perselisihan dan Pertengkaran Terus Menerus',
                           'Fakor Perceraian - Kawin Paksa', 'Fakor Perceraian - Murtad',
                           'Fakor Perceraian - Ekonomi', 'Fakor Perceraian - Lain-lain']

data_for_clustering = df_normalized[colums_for_clustering]
# Standarisasi data
scaler = StandardScaler()
data_for_clustering_scaled = scaler.fit_transform(data_for_clustering)

# Menentukan jumlah klaster (gunakan metode elbow)
inertia_values = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(data_for_clustering_scaled)
    inertia_values.append(kmeans.inertia_)

# %%
# Plot inersia untuk menentukan jumlah klaster optimal
plt.plot(range(1, 11), inertia_values, marker='o')
plt.title('Metode Elbow untuk Menentukan Jumlah Klaster Optimal')
plt.xlabel('Jumlah Klaster')
plt.ylabel('Inersia')
plt.show()

# Berdasarkan hasil metode elbow, pilih jumlah klaster optimal
jumlah_klaster_optimal = 2  # Sesuaikan dengan hasil analisis elbow Anda

# %%
kmeans = KMeans(n_clusters=7,init='k-means++',random_state=42)

# %%
y = kmeans.fit_predict(data_for_clustering_scaled)
print(y)
# Out:
# [0 0 4 0 0 4 0 0 1 3 2 0 4 0 4 0 0 0 4 0 0 4 0 0 0 0 0 6 0 0 0 0 4 5]

# %%
# Melakukan klastering dengan KMeans
kmeans = KMeans(n_clusters=jumlah_klaster_optimal, random_state=0)
merged_df['Klaster'] = kmeans.fit_predict(data_for_clustering_scaled)

# Menampilkan hasil klastering
print("Hasil Klastering:")
print(merged_df[['Provinsi', 'Klaster']])
# Out:
# Hasil Klastering:
#                      Provinsi  Klaster
# 0                        Aceh        0
# 1                        Bali        0
# 2                      Banten        0
# 3                    Bengkulu        0
# 4               DI Yogyakarta        0
# 5                 DKI Jakarta        0
# 6                   Gorontalo        0
# 7                       Jambi        0
# 8                  Jawa Barat        1
# 9                 Jawa Tengah        1
# 10                 Jawa Timur        1
# 11           Kalimantan Barat        0
# 12         Kalimantan Selatan        0
# 13          Kalimantan Tengah        0
# 14           Kalimantan Timur        0
# 15           Kalimantan Utara        0
# 16  Kepulauan Bangka Belitung        0
# 17             Kepulauan Riau        0
# 18                    Lampung        0
# 19                     Maluku        0
# 20               Maluku Utara        0
# 21        Nusa Tenggara Barat        0
# 22        Nusa Tenggara Timur        0
# 23                      Papua        0
# 24                Papua Barat        0
# 25                       Riau        0
# 26             Sulawesi Barat        0
# 27           Sulawesi Selatan        0
# 28            Sulawesi Tengah        0
# 29          Sulawesi Tenggara        0
# 30             Sulawesi Utara        0
# 31             Sumatera Barat        0
# 32           Sumatera Selatan        0
# 33             Sumatera Utara        0
