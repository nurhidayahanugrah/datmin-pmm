# 101                                                                                                                                                                                                                                                                                                                                                                                                                             3PUTRI Cap Nona 120gr Hitam,3P Cap Nona 120gr Hitam,Buffalo Baret
#
# [102 rows x 1 columns]

# %%
# Membuat list dalam list dari transaksi pembelian barang
records = []
for i in range(df.shape[0]):
    records.append([str(df.values[i,j]).split(',') for j in range(df.shape[1])])

trx = [[] for trx in range(len(records))]
for i in range(len(records)):
    for j in records[i][0]:
        trx[i].append(j)

trx
# Out:
# [['Grape Candy Duren Simadu', 'Filter Regular 50gr'],
#  ['3P ONAN 50gr Pink',
#   '3P ONAN 50gr Hitam',
#   'Surya JR Rokok 50gr',
#   'Samsu Premium JR Rokok 100gr',
#   'Leci ICE Jago rasa New50',
#   'Banana ICE Jago rasa New50',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'GAYO',
#   'Guntur Simadu',
#   'Filter Mild 14gr',
#   'Filter Klik Regular Menthol',
#   'Filter Regular 14gr',
#   'Filter Mild 50gr',
#   'RM',
#   'Buffalo Polos',
#   'Buffalo Baret'],
#  ['3PUTRI Cap Nona 100gr Pink',
#   '3P Cap Nona 100gr Pink',
#   '3P ONAN 50gr Putih',
#   '3P ONAN 50gr Hitam',
#   '3PUTRI Cap Nona 50gr merah',
#   '3P DARMAWANGI 100G',
#   'Marlboro Merah JR Rokok 100gr',
#   'Jago Mole 333 Hijau',
#   'melon Jago rasa New50',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'Whiskey Duren Simadu',
#   'Green tea Duren Simadu',
#   'Jamaica Esse Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Filter Mild 14gr',
#   'Filter Klik Regular Menthol',
#   'RM',
#   'Buffalo Baret',
#   'Mars Brand',
#   'Jamaica Esse Duren Simadu Menthol',
#   '3PUTRI Cap Nona 170gr Putih',
#   'Ppir Naraya'],
#  ['3PUTRI Cap Nona 100gr Pink',
#   '3P Cap Nona 100gr Pink',
#   '3P ONAN 50gr Putih',
#   '3P ONAN 50gr Hitam',
#   '3PUTRI Cap Nona 50gr merah',
#   '3P DARMAWANGI 100G',
#   'Marlboro Merah JR Rokok 100gr',
#   'Jago Mole 333 Hijau',
#   'melon Jago rasa New50',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'Whiskey Duren Simadu',
#   'Green tea Duren Simadu',
#   'Jamaica Esse Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Filter Mild 14gr',
#   'Filter Klik Regular Menthol',
#   'RM',
#   'Buffalo Baret',
#   'Mars Brand',
#   'Jamaica Esse Duren Simadu Menthol',
#   '3PUTRI Cap Nona 170gr Putih',
#   'Ppir Naraya'],
#  ['3P ONAN 50gr Pink',
#   '3PUTRI Cap Nona 50gr merah',
#   'Sampoerna Mild JR Rokok 50gr',
#   'Samsu Premium JR Rokok 50gr',
#   'Jago Mole 333 Hijau',
#   'Strawberry Millky SW PREMIUM',
#   'Filter Klik Regular Menthol',
#   'Buffalo Baret'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   'Black Coffe SW Prime',
#   'Guntur Simadu Menthol (Hijau)',
#   'Redwine Duren Simadu',
#   'Grape Candy Duren Simadu',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Lem V-tro besar 25gr',
#   'Filter Mild 14gr',
#   'Filter Regular 50gr',
#   'Papir rokok',
#   'RM',
#   'Buffalo Baret'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3PUTRI Cap Nona 100gr Pink',
#   '3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 120gr Hitam',
#   '3P Cap Nona 100gr Pink',
#   '3P Cap Nona 75gr Hijau',
#   '3P DARMAWANGI 100G',
#   'Surya JR Rokok 50gr',
#   'Samsu Premium JR Rokok 50gr',
#   'Surya JR Rokok 100gr',
#   'Samsu Premium JR Rokok 100gr',
#   'Mole Cap Jago Putih 100 gr',
#   'Banana ICE Jago rasa New50',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'Strawberry Millky SW PREMIUM',
#   'Black Coffe SW Prime',
#   'GAYO',
#   'Brandy Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Filter Mild 50gr',
#   'Papir rokok',
#   'RM',
#   'Buffalo Baret',
#   'Jamaica Esse Duren Simadu Menthol',
#   'kotak jinggo'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3PUTRI Cap Nona 100gr Pink',
#   '3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 120gr Hitam',
#   '3P Cap Nona 100gr Pink',
#   '3P Cap Nona 75gr Hijau',
#   '3P DARMAWANGI 100G',
#   'Surya JR Rokok 50gr',
#   'Samsu Premium JR Rokok 50gr',
#   'Surya JR Rokok 100gr',
#   'Samsu Premium JR Rokok 100gr',
#   'Mole Cap Jago Putih 100 gr',
#   'Banana ICE Jago rasa New50',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'Strawberry Millky SW PREMIUM',
#   'Black Coffe SW Prime',
#   'GAYO',
#   'Brandy Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Filter Mild 50gr',
#   'Papir rokok',
#   'RM',
#   'Buffalo Baret',
#   'Jamaica Esse Duren Simadu Menthol',
#   'kotak jinggo'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3PUTRI Cap Nona 100gr Pink',
#   '3P Cap Nona 120gr Hitam',
#   '3P Cap Nona 100gr Pink',
#   'Banana ICE Jago rasa New50',
#   'Redwine Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Filter Klik Regular Menthol',
#   'Filter Regular 14gr',
#   'RM',
#   'Buffalo Baret'],
#  ['Warning 50gr',
#   'Black Coffe SW Prime',
#   'KASTURI 30G',
#   'GAYO',
#   'Cappuchino Milk Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Filter Regular 14gr',
#   'RM',
#   'Buffalo Baret'],
#  ['3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 75gr Hijau',
#   'Marlboro Menthol JR Rokok 100gr',
#   'GAYO',
#   'Guntur Simadu',
#   'Black Wine Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Alat Lintink Kecil Mild',
#   'Filter Regular 14gr',
#   'Filter Regular 50gr',
#   'Filter Mild 50gr',
#   'Burung Hantu',
#   'Buffalo Baret',
#   'Mars Brand',
#   'Jamaica Esse Duren Simadu Menthol'],
#  ['3PUTRI Cap Nona 100gr Pink',
#   '3P Cap Nona 100gr Pink',
#   'Sampoerna Mild JR Rokok 50gr',
#   'Indomie Goreng',
#   'Violin 40gr',
#   'Alat Linting Kecil Regular',
#   'Filter Klik Regular Menthol',
#   'Filter Regular 14gr',
#   'RM'],
#  ['Sampoerna Mild JR Rokok 50gr',
#   'Surya JR Rokok 50gr',
#   'Banana ICE Jago rasa New50',
#   'Warning 50gr',
#   'Black Coffe SW Prime',
#   'GAYO',
#   'Guntur Simadu Menthol (Hijau)',
#   'Filter Mild 14gr',
#   'Filter Regular 14gr',
#   'RM',
#   'kotak jinggo',
#   'Vanilla Milky Duren Simadu'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3PUTRI Cap Nona 100gr Pink',
#   '3P Cap Nona 120gr Hitam',
#   '3P Cap Nona 100gr Pink',
#   'Banana ICE Jago rasa New50',
#   'Redwine Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Filter Klik Regular Menthol',
#   'Filter Regular 14gr',
#   'RM',
#   'Buffalo Baret'],
#  ['Warning 50gr',
#   'Black Coffe SW Prime',
#   'KASTURI 30G',
#   'GAYO',
#   'Cappuchino Milk Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Filter Regular 14gr',
#   'RM',
#   'Buffalo Baret'],
#  ['kotak jinggo'],
#  ['Kotak Rokok', 'Virgin Apple'],
#  ['Grape ICE Jago rasa New50'],
#  ['3PUTRI Cap Nona 100gr Pink', '3P Cap Nona 100gr Pink', 'Buffalo Baret'],
#  ['Banana ICE Jago rasa New50'],
#  ['Black Coffe SW Prime'],
#  ['RM', 'SW White Coffe'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   'Filter Mild 14gr',
#   'Ppir Naraya'],
#  ['Samsu Premium JR Rokok 100gr'],
#  ['3PUTRI Cap Nona 100gr Pink', '3P Cap Nona 100gr Pink', 'Burung Hantu'],
#  ['Buffalo Baret', 'Country Man'],
#  ['3P Cap Nona 150gr Hitam'],
#  ['Banana ICE Jago rasa New50'],
#  ['Whiskey Duren Simadu',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Buffalo Baret'],
#  ['Filter Mild 14gr', 'RM'],
#  ['Banana ICE Jago rasa New50', 'Alat Lintink Kecil Mild', 'Buffalo Baret'],
#  ['Kotak Rokok'],
#  ['Mars Brand'],
#  ['Banana ICE Jago rasa New50', 'Lem V-tro kecil 10gr'],
#  ['GAYO'],
#  ['3PUTRI Cap Nona 120gr Hitam', '3P Cap Nona 120gr Hitam'],
#  ['Black Coffe SW Prime', 'Kotak Rokok'],
#  ['Buffalo Baret'],
#  ['Buffalo Baret'],
#  ['Samsu Premium JR Rokok 50gr', 'Lem V-tro kecil 10gr'],
#  ['Black Coffe SW Prime', 'Buffalo Baret'],
#  ['Black Coffe SW Prime', 'Buffalo Baret'],
#  ['3PUTRI Cap Nona 120gr Hitam', '3P Cap Nona 120gr Hitam'],
#  ['Warning 50gr', 'GAYO', 'Guntur Simadu (Hitam)'],
#  ['3P Cap Nona 150gr Hitam', 'Buffalo Baret'],
#  ['Warning 50gr',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Buffalo Baret'],
#  ['Sampoerna Mild JR Rokok 100gr'],
#  ['Marlboro Merah JR Rokok 100gr', 'Buffalo Baret'],
#  ['Sampoerna Mild JR Rokok 100gr', 'Buffalo Baret'],
#  ['Duren Simadu Soju Mint'],
#  ['Tembakau Mole cap Jago Jebra Hitam 50gr', 'Ppir Naraya'],
#  ['Grape ICE Jago rasa New50'],
#  ['Lem V-tro besar 25gr', 'Duren Simadu Strawbery Milky Ice'],
#  ['Duren Simadu Strawbery Milky Ice'],
#  ['Surya JR Rokok 100gr', 'Papir rokok', 'kotak jinggo', 'Buffalo Baret'],
#  ['Papir pabrikan'],
#  ['3P ONAN 50gr Putih', 'Buffalo Baret'],
#  ['3P ONAN 50gr Putih'],
#  ['Lem V-tro kecil 10gr', 'Ppir Naraya', 'Cengkeh'],
#  ['Samsu JR Rokok 50gr', 'RM', 'Buffalo Baret'],
#  ['Sampoerna Mild JR Rokok 50gr', 'Buffalo Baret'],
#  ['Samsu Premium JR Rokok 100gr'],
#  ['Filter Mild 50gr', 'Buffalo Baret'],
#  ['Sampoerna Mild JR Rokok 50gr',
#   'Samsu Premium JR Rokok 50gr',
#   'Sampoerna Mild JR Rokok 100gr',
#   'Black Coffe SW Prime',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro besar 25gr',
#   'Filter Mild 14gr',
#   'RM'],
#  ['Grape ICE Jago rasa New50',
#   'Cappuchino Milk Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Papir rokok',
#   'RM',
#   'Ppir Naraya',
#   'Buffalo Baret',
#   'Violin',
#   'Country Man',
#   'Cengkeh'],
#  ['Sampoerna Mild JR Rokok 50gr',
#   'Sampoerna Mild JR Rokok 100gr',
#   'Samsu Premium JR Rokok 100gr',
#   'Warning 50gr',
#   'Guntur Simadu (Hitam)',
#   'Alat Slorok',
#   '3P Cap Nona 150gr Hitam',
#   'Buffalo Baret',
#   'Violin',
#   'Royal Bourbon',
#   'Cengkeh',
#   'Duren Simadu Strawbery Milky Ice'],
#  ['3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 75gr Hijau',
#   'Black Coffe SW Prime',
#   'Guntur Simadu',
#   'Papir rokok',
#   'RM',
#   'Buffalo Baret',
#   'Duren Simadu Bubblegum Ice'],
#  ['RM'],
#  ['Sampoerna Mild JR Rokok 100gr',
#   'Tembakau Mole cap Jago Jebra Pink 50gr',
#   'GAYO',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Ppir Naraya',
#   'Buffalo Baret'],
#  ['Marlboro Menthol JR Rokok 50gr',
#   'Jago Mole 333 Kuning',
#   'Mole Cap Jago Putih 100 gr',
#   'Banana ICE Jago rasa New50',
#   'Green tea Duren Simadu',
#   'Lem V-tro kecil 10gr',
#   'Alat Slorok',
#   'Buffalo Baret',
#   'Filter Klik Regular Menthol 50gr',
#   'Papir Naraya Merah'],
#  ['Mole cap Jago Orange 70 gr',
#   'Banana ICE Jago rasa New50',
#   'Warning 50gr',
#   'Strawberry Millky SW PREMIUM',
#   'Mars Brand',
#   'Buffalo Baret',
#   'Narayana',
#   'Duren Simadu Soju Mint'],
#  ['3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 75gr Hijau',
#   'Marlboro Menthol JR Rokok 100gr',
#   'Jago Mole 333 Kuning',
#   'Tembakau Mole cap Jago Jebra Hijau 50gr',
#   'Guntur Simadu',
#   'RM',
#   'Buffalo Baret',
#   'Narayana',
#   'Duren Simadu Bubblegum Ice'],
#  ['3P ONAN 50gr Putih',
#   'Alat Linting Kecil Regular',
#   'Buffalo Baret',
#   'Duren Simadu Strawbery Milky Ice'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 120gr Hitam',
#   '3P Cap Nona 75gr Hijau',
#   '3P ONAN 50gr Putih',
#   'Sampoerna Mild JR Rokok 50gr',
#   'Surya JR Rokok 50gr',
#   'Samsu Premium JR Rokok 50gr',
#   'Banana ICE Jago rasa New50',
#   'Strawberry Millky SW PREMIUM',
#   'Black Coffe SW Prime',
#   'Vanilla Sweet Duren Simadu',
#   'Lem V-tro kecil 10gr',
#   'Filter Regular 14gr',
#   'RM',
#   '3PUTRI Cap Nona 170gr Putih',
#   'Ppir Naraya',
#   'Buffalo Baret',
#   'Cengkeh',
#   'SW White Coffe',
#   'Virgin Vanilla',
#   'Papir Naraya Merah',
#   'Duren Simadu Strawbery Milky Ice',
#   'BUSA Regular 35gr',
#   'BUSA Mild 35gr',
#   'BUSA Karkol 50Gr',
#   'BUSA Regular Menthol 35Gr',
#   'Plastik Alat Linting',
#   'BUSA Klik Regular Menthol 35Gr'],
#  ['Tembakau Mole cap Jago Jebra Pink 50gr',
#   'Grape ICE Jago rasa New50',
#   'Warning 50gr',
#   'Cappucino choice SW PREMIUM',
#   'Mole Aroma SW PREMIUM',
#   'Black Coffe SW Prime',
#   'Vanilla Sweet Duren Simadu',
#   'Alat Linting Kecil Regular',
#   'Burung Hantu',
#   'Ppir Naraya',
#   'Country Man',
#   'SW White Coffe'],
#  ['Black Coffe SW Prime',
#   'Guntur Simadu',
#   'Alat Lintink Kecil Mild',
#   'Kotak Rokok',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Filter Regular 50gr',
#   'kotak jinggo',
#   'Buffalo Baret',
#   'Virgin Apple',
#   'Duren Simadu Silky Melon Mint',
#   'Duren Simadu Greentea Mint'],
#  ['Black Coffe SW Prime',
#   'Guntur Simadu',
#   'Alat Lintink Kecil Mild',
#   'Kotak Rokok',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Filter Regular 50gr',
#   'kotak jinggo',
#   'Buffalo Baret',
#   'Virgin Apple',
#   'Duren Simadu Silky Melon Mint',
#   'Duren Simadu Greentea Mint'],
#  ['Black Coffe SW Prime',
#   'Guntur Simadu',
#   'Alat Lintink Kecil Mild',
#   'Kotak Rokok',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Filter Regular 50gr',
#   'kotak jinggo',
#   'Buffalo Baret',
#   'Virgin Apple',
#   'Duren Simadu Silky Melon Mint',
#   'Duren Simadu Greentea Mint'],
#  ['Virgin Apple', 'BUSA Klik Regular Menthol 35Gr'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   '3P ONAN 50gr Pink',
#   'Banana ICE Jago rasa New50',
#   'Black Coffe SW Prime',
#   'GAYO',
#   'Alat Lintink Kecil Mild',
#   'Kotak Rokok',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Alat Slorok',
#   'RM',
#   'Buffalo Baret',
#   'Virgin Apple',
#   'Papir pabrikan',
#   'BUSA Regular 35gr'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   '3P ONAN 50gr Pink',
#   'Banana ICE Jago rasa New50',
#   'Black Coffe SW Prime',
#   'GAYO',
#   'Alat Lintink Kecil Mild',
#   'Kotak Rokok',
#   'Lem V-tro kecil 10gr',
#   'Filter Mild 14gr',
#   'Alat Slorok',
#   'RM',
#   'Buffalo Baret',
#   'Virgin Apple',
#   'Papir pabrikan',
#   'BUSA Regular 35gr'],
#  ['Marlboro Merah JR Rokok 50gr',
#   'Banana ICE Jago rasa New50',
#   'Warning 50gr',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Alat Slorok',
#   '3PUTRI Cap Nona 170gr Putih',
#   'Buffalo Baret',
#   'Papir pabrikan',
#   'Country Man',
#   'Duren Simadu Silky Melon Mint',
#   'Duren Simadu Greentea Mint',
#   'BUSA Regular 35gr'],
#  ['Marlboro Merah JR Rokok 50gr',
#   'Banana ICE Jago rasa New50',
#   'Warning 50gr',
#   'Alat Linting Kecil Regular',
#   'Lem V-tro kecil 10gr',
#   'Alat Slorok',
#   '3PUTRI Cap Nona 170gr Putih',
#   'Buffalo Baret',
#   'Papir pabrikan',
#   'Country Man',
#   'Duren Simadu Silky Melon Mint',
#   'Duren Simadu Greentea Mint',
#   'BUSA Regular 35gr'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   'BUSA Regular 35gr'],
#  ['3PUTRI Cap Nona 75gr Hijau',
#   '3P Cap Nona 75gr Hijau',
#   '3P ONAN 50gr Putih',
#   'Samsu Premium JR Rokok 100gr',
#   'Green tea Duren Simadu',
#   'Narayana',
#   'Duren Simadu Strawbery Milky Ice'],
#  ['Sampoerna Mild JR Rokok 50gr', 'Buffalo Baret'],
#  ['Sampoerna Mild JR Rokok 50gr',
#   'Cappuchino Milk Duren Simadu',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Lem V-tro besar 25gr',
#   '3P Cap Nona 150gr Hitam',
#   'Buffalo Baret',
#   'Duren Simadu Silky Melon Mint'],
#  ['Buffalo Baret', 'Plastik Alat Linting'],
#  ['Warning 50gr',
#   'Whisky choice SW PREMIUM',
#   'Alat Lintink Kecil Mild',
#   'Lem V-tro kecil 10gr',
#   'Papir rokok',
#   'Buffalo Baret',
#   'Duren Simadu Bubblegum Ice',
#   'BUSA Mild 35gr'],
#  ['Narayana'],
#  ['3P ONAN 50gr Putih',
#   'Sampoerna Mild JR Rokok 100gr',
#   'Grape ICE Jago rasa New50',
#   'Warning 50gr',
#   'Cappucino choice SW PREMIUM',
#   'Burung Hantu',
#   'Buffalo Baret',
#   'Violin',
#   'Cengkeh',
#   'Tasty Manggo',
#   'BUSA Regular Menthol 35Gr'],
#  ['Lem V-tro besar 25gr',
#   'RM',
#   'BUSA Regular 35gr',
#   'BUSA Klik Regular Menthol 35Gr'],
#  ['Duren Simadu Manggo Mint'],
#  ['3P ONAN 50gr Hitam'],
#  ['BUSA Regular 35gr'],
#  ['Duren Simadu Banana Milky Ice'],
#  ['Warning 50gr',
#   'Lem V-tro kecil 10gr',
#   'Lem V-tro besar 25gr',
#   'Buffalo Baret',
#   'Tasty Manggo',
#   'Plastik Alat Linting'],
#  ['3PUTRI Cap Nona 120gr Hitam',
#   '3P Cap Nona 120gr Hitam',
#   'Buffalo Baret',
#   'Cengkeh',
#   'Duren Simadu Banana Milky Ice',
#   'BUSA Mild 35gr',
#   'BUSA Mild Menthol 35gr',
#   'Plastik Alat Linting',
#   'curah mild 100gr'],
#  ['3PUTRI Cap Nona 100gr Pink', '3P Cap Nona 100gr Pink'],
#  ['3P ONAN 50gr Putih',
#   'Marlboro Merah JR Rokok 100gr',
#   'Buffalo Baret',
#   'Narayana',
#   'Cengkeh',
#   'Duren Simadu Silky Melon Mint',
#   'BUSA Karkol 50Gr'],
#  ['Marlboro Menthol JR Rokok 50gr',
#   'Warning 50gr',
#   'Black Coffe SW Prime',
#   'Lem V-tro kecil 10gr',
#   'Buffalo Baret',
#   'BUSA Mild 35gr'],
#  ['3PUTRI Cap Nona 120gr Hitam', '3P Cap Nona 120gr Hitam', 'Buffalo Baret']]

# %%
# Menggunakan fungsi apriori untuk membuat asosiasi
association_rules = apriori(trx, min_support=0.14, min_confidence=0.80,min_lift=1)
# Membuat list hasil dari algoritma apriori
association_results = association_rules

# %%
# Menampilkan hasil asosiasi dari item 
pd.set_option('max_colwidth', 1000)
Result=pd.DataFrame(columns=['Rule','Support','Confidence'])
for item in association_results:
    pair = item[2]
    for i in pair:
        items = str([x for x in i[0]])
        if i[3]!=1:
            Result=Result.append({
                'Rule':str([x for x in i[0]])+ " -> " +str([x for x in i[1]]),
                'Support':str(round(item[1]*100,2))+'%',
                'Confidence':str(round(i[2] *100,2))+'%'
                },ignore_index=True)
Result
# Out:
# C:\Users\MSi-Modern\AppData\Local\Temp\ipykernel_15668\1331803998.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Result=Result.append({
# C:\Users\MSi-Modern\AppData\Local\Temp\ipykernel_15668\1331803998.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Result=Result.append({
#                                                   Rule Support Confidence
# 0  ['Alat Linting Kecil Regular'] -> ['Buffalo Baret']  14.71%     83.33%
# 1        ['Lem V-tro kecil 10gr'] -> ['Buffalo Baret']  21.57%      88.0%
